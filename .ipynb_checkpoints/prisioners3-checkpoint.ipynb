# %% [markdown]
# ### Prisioner's Dilemma (Single Agent)
#
# - There is a single agent that interact in repeated prisioner's dilemma.
# - Actions are: defect (D/0) or confess (C/1).
# - There is one state that is the other bot's last play (this is memory).
# - The other agent is just a deterministic bot (plays tit-for-tat or grim trigger)
# - Rewards for agents are
#
#     - (3,3) for (D,D)
#     - (0,5) for (D,C)
#     - (5,0) for (C,D)
#     - (1,1) for (C,C)
#
# - There is "discounting". Agents do value future profits.
# - We simulate 3 scenarios:
#     - Deterministic bot plays C only
#     - Deterministic bot plays D only
#     - Deterministic bot plays Tit-for-tat

# %% [markdown]
# ### Import Packages

# %%
from itertools import count
import torch
import math
import torch.optim as optim 
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (30, 10)
plt.rcParams['font.size']=20

# %% [markdown]
# ### Helper Functions

# %%
def gameReward(a1,a2):
    if (a1 == 0 and a2 == 0): # DD
        return (1,1)
    if (a1 == 0 and a2 == 1): # DC
        return (3,0)
    if (a1 == 1 and a2 == 0): # CD
        return (0,3)
    if (a1 == 1 and a2 == 1): # CC
        return (2.5,2.5)
   
def deterministicBot(a1_old):
    if (a1_old == 0): 
        return 0
    if (a1_old == 1): 
        return 1
    
import random
from collections import namedtuple, deque
Transition = namedtuple('Transition',('state','next_state','a1','a2','r1','r2'))

class ReplayMemory(object):
    # Holds transitions from experience and gives a random batch of transitions for training
    def __init__(self,capacity):
        self.memory = deque([], maxlen=capacity)
    def push(self,*args):
        "save transition"
        self.memory.append(Transition(*args))
        
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

class DQN(nn.Module):
    # Input: State, Output: Value of actions (0/1)
    # Network predicts the expected Return of taking each action given the state
    def __init__(self, n_obs, n_actions):
        super(DQN,self).__init__()
        self.layer1 = nn.Linear(n_obs, 128)
        self.layer2 = nn.Linear(128,128)
        self.layer3 = nn.Linear(128, n_actions)
    
    def forward(self,x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)   


def select_action(state, policy_net, idx):
    # Given state selects action either from the DQN or randomly. 
    global steps_done1, steps_done2
    sample = random.random()
    if idx == 0:
        eps_threshold = EPS_END + (EPS_START-EPS_END)*math.exp(-1.*steps_done1/EPS_DECAY)
        steps_done1 += 1
    else:
        eps_threshold = EPS_END + (EPS_START-EPS_END)*math.exp(-1.*steps_done2/EPS_DECAY)
        steps_done2 += 1
    
    if sample>eps_threshold:
        with torch.no_grad():
            try: 
                return policy_net(state).max(1)[1].view(1,1) # pick up action with largest expected reward
            except:
                return policy_net(state).max(0)[1].view(1,1) # pick up action with largest expected reward
    else:
        randchoice = random.choice([0,1])
        return torch.tensor([[randchoice]],dtype=torch.long)
    
def update_target_net(target_net, policy_net):
    target_net_state_dict = target_net.state_dict()
    policy_net_state_dict = policy_net.state_dict()
    for key in policy_net_state_dict:
        target_net_state_dict[key] = policy_net_state_dict[key]*TAU+target_net_state_dict[key]*(1-TAU)
    target_net.load_state_dict(target_net_state_dict)

def optimize_model(policy_net,target_net,idx):
    if len(memory)<BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions))
    
    # final state is after simulation is done
    # these are the "s(t+1)" from the transitions
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None, batch.next_state)),dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
    
    # we begin with a batch of transitions - (state, action, reward)
    state_batch = torch.cat(batch.state)
    if idx == 0:
        action_batch = torch.cat(batch.a1)
        reward_batch = torch.cat(batch.r1)
    elif idx == 1:
        action_batch = torch.cat(batch.a2)
        reward_batch = torch.cat(batch.r2)
    
    # For these batch states we compute optimal policy according to our policy-network
    # Compute Q(s,a) and get actions - these are the actions that would have been taken for each batch state 
    state_action_values = policy_net(state_batch.reshape(-1,1)).gather(1,action_batch)
    
    # Compute V(s_t+1)
    next_state_values = torch.zeros(BATCH_SIZE)
    with torch.no_grad():
        # Use the "old" target_net to obtain value (Expected Return) on optimal actions from sampled s(t+1)
        # This is Q_old(s',a')
        next_state_values[non_final_mask] = target_net(non_final_next_states.reshape(-1,1)).max(1)[0]
        
    # Here we have add r + max Q_old(s',a')
    expected_state_action_values = (next_state_values*GAMMA)+reward_batch

    # Compute the loss
    # Q_new(s,a) - r + max Q_old(s',a'): is the error
    # Huber loss function
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values,expected_state_action_values.unsqueeze(1))
    if idx == 0:
        optimizer1.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_value_(policy_net1.parameters(),100)
        optimizer1.step()
    elif idx == 1:
        optimizer2.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_value_(policy_net2.parameters(),100)
        optimizer2.step()
    print(f'Loss Agent{idx}:{loss.item()}')

# %% [markdown]
# ### HyperParameters and Initializations

# %%
BATCH_SIZE = 128 # number of transitions sampled from replay buffer
GAMMA = 0.99 # Discount factor
EPS_START = 0.9 # Initial value of Epsilon
EPS_END = 0.05 # End value of Epsilon
EPS_DECAY = 1000 # controls decay rate of Epsilon
TAU = 0.005 # update rate of target network
LR = 1e-4 # Learning rate of Adam
n_obs = 1
n_actions = 2
policy_net1 = DQN(n_obs,n_actions)
target_net1 = DQN(n_obs,n_actions)
steps_done1 = 0
optimizer1 = optim.AdamW(policy_net1.parameters(),lr=LR,amsgrad=True)
memory=ReplayMemory(10000)

# %% [markdown]
# ### Training Loop

# %%
state = torch.tensor(1,dtype=torch.float32).unsqueeze(0)
actions = []
epochs = 10000

state = torch.tensor(int(0),dtype=torch.float32).unsqueeze(0)
a1 = torch.tensor(int(0),dtype=torch.float32).unsqueeze(0)

for t in range(epochs):
    print('\n Iteration:',t)
    
    # Take action
    a2 = deterministicBot(int(a1)) # bot takes action based off past policy
    a1 = select_action(state, policy_net1, 0)

    # Obtain Rewards
    r1, r2 = gameReward(int(a1),int(a2))
    r1 = torch.tensor([r1])

    # Compute next state (which is the opponents' strategy)
    next_state = torch.tensor(int(a2),dtype=torch.float32).unsqueeze(0)

    # store memory in transition
    memory.push(state,next_state,a1,a2,r1,r2)

    # move to next state
    state = next_state

    # optimize
    optimize_model(policy_net1,target_net1, 0)

    # soft update target_net
    update_target_net(target_net1, policy_net1)
    
    # record actions
    actions.append([int(a1),int(a2)])
# Out:
#  Iteration: 0
#
#  Iteration: 1
#
#  Iteration: 2
#
#  Iteration: 3
#
#  Iteration: 4
#
#  Iteration: 5
#
#  Iteration: 6
#
#  Iteration: 7
#
#  Iteration: 8
#
#  Iteration: 9
#
#  Iteration: 10
#
#  Iteration: 11
#
#  Iteration: 12
#
#  Iteration: 13
#
#  Iteration: 14
#
#  Iteration: 15
#
#  Iteration: 16
#
#  Iteration: 17
#
#  Iteration: 18
#
#  Iteration: 19
#
#  Iteration: 20
#
#  Iteration: 21
#
#  Iteration: 22
#
#  Iteration: 23
#
#  Iteration: 24
#
#  Iteration: 25
#
#  Iteration: 26
#
#  Iteration: 27
#
#  Iteration: 28
#
#  Iteration: 191
# Loss Agent0:0.8100202679634094
#
#  Iteration: 192
# Loss Agent0:0.845294713973999
#
#  Iteration: 193
# Loss Agent0:0.7720566987991333
#
#  Iteration: 194
# Loss Agent0:0.8096632361412048
#
#  Iteration: 195
# Loss Agent0:0.8031386137008667
#
#  Iteration: 196
# Loss Agent0:0.7555190920829773
#
#  Iteration: 197
# Loss Agent0:0.8403341770172119
#
#  Iteration: 198
# Loss Agent0:0.7628811597824097
#
#  Iteration: 199
# Loss Agent0:0.794818103313446
#
#  Iteration: 200
# Loss Agent0:0.792646586894989
#
#  Iteration: 201
# Loss Agent0:0.7907954454421997
#
#  Iteration: 202
# Loss Agent0:0.7545055150985718
#
#  Iteration: 203
# Loss Agent0:0.749660074710846
#
#  Iteration: 204
# Loss Agent0:0.6975857019424438
#
#  Iteration: 205
# Loss Agent0:0.7155545949935913
#
#  Iteration: 206
# Loss Agent0:0.7212604880332947
#
#  Iteration: 207
# Loss Agent0:0.6578949093818665
#
#  Iteration: 208
# Loss Agent0:0.7260408401489258
#
#  Iteration: 209
# Loss Agent0:0.6812768578529358
#
#  Iteration: 210
# Loss Agent0:0.6591503620147705
#
#  Iteration: 211
# Loss Agent0:0.6414018869400024
#
#  Iteration: 212
# Loss Agent0:0.753248393535614
#
#  Iteration: 213
# Loss Agent0:0.6135390400886536
#
#  Iteration: 214
# Loss Agent0:0.711166262626648
#
#  Iteration: 215
# Loss Agent0:0.6530270576477051
#
#  Iteration: 216
# Loss Agent0:0.6831759214401245
#
#  Iteration: 217
# Loss Agent0:0.6664024591445923
#
#  Iteration: 218
# Loss Agent0:0.624895453453064
#
#  Iteration: 219
# Loss Agent0:0.6359847187995911
#
#  Iteration: 220
# Loss Agent0:0.7051358222961426
#
#  Iteration: 221
# Loss Agent0:0.7299565672874451
#
#  Iteration: 222
# Loss Agent0:0.6838380694389343
#
#  Iteration: 223
# Loss Agent0:0.648784875869751
#
#  Iteration: 224
# Loss Agent0:0.5649350881576538
#
#  Iteration: 225
# Loss Agent0:0.6589827537536621
#
#  Iteration: 226
# Loss Agent0:0.6303111910820007
#
#  Iteration: 227
# Loss Agent0:0.7091465592384338
#
#  Iteration: 228
# Loss Agent0:0.7176625728607178
#
#  Iteration: 229
# Loss Agent0:0.5761448740959167
#
#  Iteration: 230
# Loss Agent0:0.7183166146278381
#
#  Iteration: 231
# Loss Agent0:0.6176843047142029
#
#  Iteration: 232
# Loss Agent0:0.647049069404602
#
#  Iteration: 233
# Loss Agent0:0.7161577939987183
#
#  Iteration: 234
# Loss Agent0:0.6339420080184937
#
#  Iteration: 235
# Loss Agent0:0.6471844911575317
#
#  Iteration: 236
# Loss Agent0:0.6747263073921204
#
#  Iteration: 237
# Loss Agent0:0.684396505355835
#
#  Iteration: 238
# Loss Agent0:0.649299144744873
#
#  Iteration: 239
# Loss Agent0:0.6371917724609375
#
#  Iteration: 240
# Loss Agent0:0.5594869256019592
#
#  Iteration: 241
# Loss Agent0:0.5570008754730225
#
#  Iteration: 242
# Loss Agent0:0.5810998678207397
# Loss Agent0:0.5774010419845581
#
#  Iteration: 502
# Loss Agent0:0.634029746055603
#
#  Iteration: 503
# Loss Agent0:0.5805441737174988
#
#  Iteration: 504
# Loss Agent0:0.5736876726150513
#
#  Iteration: 505
# Loss Agent0:0.5145058035850525
#
#  Iteration: 506
# Loss Agent0:0.6283549666404724
#
#  Iteration: 507
# Loss Agent0:0.5626401901245117
#
#  Iteration: 508
# Loss Agent0:0.5303158760070801
#
#  Iteration: 509
# Loss Agent0:0.5717063546180725
#
#  Iteration: 510
# Loss Agent0:0.619038462638855
#
#  Iteration: 511
# Loss Agent0:0.5350527763366699
#
#  Iteration: 512
# Loss Agent0:0.5709797739982605
#
#  Iteration: 513
# Loss Agent0:0.5442914962768555
#
#  Iteration: 514
# Loss Agent0:0.5174116492271423
#
#  Iteration: 515
# Loss Agent0:0.6185808181762695
#
#  Iteration: 516
# Loss Agent0:0.668709933757782
#
#  Iteration: 517
# Loss Agent0:0.6468114852905273
#
#  Iteration: 518
# Loss Agent0:0.6403120756149292
#
#  Iteration: 519
# Loss Agent0:0.5045690536499023
#
#  Iteration: 520
# Loss Agent0:0.603134274482727
#
#  Iteration: 521
# Loss Agent0:0.604817271232605
#
#  Iteration: 522
# Loss Agent0:0.5320606231689453
#
#  Iteration: 523
# Loss Agent0:0.6146504878997803
#
#  Iteration: 524
# Loss Agent0:0.5933499932289124
#
#  Iteration: 525
# Loss Agent0:0.5388448238372803
#
#  Iteration: 526
# Loss Agent0:0.49582439661026
#
#  Iteration: 527
# Loss Agent0:0.5313943028450012
#
#  Iteration: 528
# Loss Agent0:0.618457019329071
#
#  Iteration: 529
# Loss Agent0:0.6421180963516235
#
#  Iteration: 530
# Loss Agent0:0.6152704358100891
#
#  Iteration: 531
# Loss Agent0:0.6098266839981079
#
#  Iteration: 532
# Loss Agent0:0.6602939367294312
#
#  Iteration: 533
# Loss Agent0:0.5637472867965698
#
#  Iteration: 534
# Loss Agent0:0.5790833830833435
#
#  Iteration: 535
# Loss Agent0:0.5568515658378601
#
#  Iteration: 536
# Loss Agent0:0.5363916158676147
#
#  Iteration: 537
# Loss Agent0:0.4999862611293793
#
#  Iteration: 538
# Loss Agent0:0.49440714716911316
#
#  Iteration: 539
# Loss Agent0:0.5961857438087463
#
#  Iteration: 540
# Loss Agent0:0.48610201478004456
#
#  Iteration: 541
# Loss Agent0:0.43463054299354553
#
#  Iteration: 542
# Loss Agent0:0.6489318013191223
#
#  Iteration: 543
# Loss Agent0:0.49649134278297424
#
#  Iteration: 544
# Loss Agent0:0.5384536385536194
#
#  Iteration: 545
# Loss Agent0:0.5574124455451965
#
#  Iteration: 546
# Loss Agent0:0.5725468397140503
#
#  Iteration: 547
# Loss Agent0:0.5792174935340881
#
#  Iteration: 548
# Loss Agent0:0.5698802471160889
#
#  Iteration: 549
# Loss Agent0:0.5696269273757935
#
#  Iteration: 550
# Loss Agent0:0.5503825545310974
#
#  Iteration: 551
# Loss Agent0:0.520143985748291
#
#  Iteration: 552
# Loss Agent0:0.5331336259841919
#
#  Iteration: 553
# Loss Agent0:0.5043563842773438
#
#  Iteration: 554
# Loss Agent0:0.5301394462585449
#
#  Iteration: 555
# Loss Agent0:0.5557436943054199
#
#  Iteration: 556
# Loss Agent0:0.5103524923324585
#
#  Iteration: 557
# Loss Agent0:0.5058547854423523
#
#  Iteration: 558
# Loss Agent0:0.60746830701828
#
#  Iteration: 559
# Loss Agent0:0.5460644364356995
#
#  Iteration: 560
# Loss Agent0:0.6108680963516235
#
#  Iteration: 561
# Loss Agent0:0.5565420389175415
#
#  Iteration: 562
# Loss Agent0:0.5162686109542847
#
#  Iteration: 563
# Loss Agent0:0.5026744604110718
#
#  Iteration: 564
# Loss Agent0:0.5771358609199524
#
#  Iteration: 565
# Loss Agent0:0.5886253118515015
#
#  Iteration: 566
# Loss Agent0:0.56290602684021
#
#  Iteration: 567
# Loss Agent0:0.5273356437683105
#
#  Iteration: 568
# Loss Agent0:0.5234347581863403
#
#  Iteration: 569
# Loss Agent0:0.48401889204978943
#
#  Iteration: 570
# Loss Agent0:0.5801075100898743
#
#  Iteration: 571
# Loss Agent0:0.481932669878006
#
#  Iteration: 572
# Loss Agent0:0.532246470451355
#
#  Iteration: 573
# Loss Agent0:0.5569533109664917
#
#  Iteration: 574
# Loss Agent0:0.5370124578475952
#
#  Iteration: 575
# Loss Agent0:0.4697449505329132
#
#  Iteration: 576
# Loss Agent0:0.48907470703125
#
#  Iteration: 577
# Loss Agent0:0.5800216197967529
#
#  Iteration: 578
# Loss Agent0:0.4960886836051941
#
#  Iteration: 579
# Loss Agent0:0.4771537184715271
#
#  Iteration: 580
# Loss Agent0:0.5714471340179443
#
#  Iteration: 581
# Loss Agent0:0.6111797094345093
#
#  Iteration: 582
# Loss Agent0:0.5309060215950012
#
#  Iteration: 583
# Loss Agent0:0.40060940384864807
#
#  Iteration: 584
# Loss Agent0:0.6311163902282715
#
#  Iteration: 585
# Loss Agent0:0.49638405442237854
#
#  Iteration: 586
# Loss Agent0:0.5486664772033691
#
#  Iteration: 587
# Loss Agent0:0.5640076994895935
#
#  Iteration: 588
# Loss Agent0:0.5389397144317627
#
#  Iteration: 589
# Loss Agent0:0.6103779077529907
#
#  Iteration: 590
# Loss Agent0:0.5123202800750732
#
#  Iteration: 591
# Loss Agent0:0.4735686480998993
#
#  Iteration: 592
# Loss Agent0:0.5744077563285828
#
#  Iteration: 593
# Loss Agent0:0.5039364695549011
#
#  Iteration: 594
# Loss Agent0:0.5321493148803711
#
#  Iteration: 595
# Loss Agent0:0.4851049482822418
#
#  Iteration: 596
# Loss Agent0:0.5826448202133179
#
#  Iteration: 597
# Loss Agent0:0.5042036771774292
#
#  Iteration: 598
# Loss Agent0:0.569303572177887
#
#  Iteration: 599
# Loss Agent0:0.5394471883773804
#
#  Iteration: 600
# Loss Agent0:0.532789409160614
#
#  Iteration: 601
# Loss Agent0:0.49530619382858276
#
#  Iteration: 602
# Loss Agent0:0.5189306735992432
#
#  Iteration: 603
# Loss Agent0:0.6302714347839355
#
#  Iteration: 604
# Loss Agent0:0.5154374837875366
#  Iteration: 966
# Loss Agent0:0.44376513361930847
#
#  Iteration: 967
# Loss Agent0:0.39525753259658813
#
#  Iteration: 968
# Loss Agent0:0.3938162922859192
#
#  Iteration: 969
# Loss Agent0:0.45816707611083984
#
#  Iteration: 970
# Loss Agent0:0.3802562952041626
#
#  Iteration: 971
# Loss Agent0:0.3682408332824707
#
#  Iteration: 972
# Loss Agent0:0.38417190313339233
#
#  Iteration: 973
# Loss Agent0:0.36580026149749756
#
#  Iteration: 974
# Loss Agent0:0.2929005026817322
#
#  Iteration: 975
# Loss Agent0:0.39087632298469543
#
#  Iteration: 976
# Loss Agent0:0.33339717984199524
#
#  Iteration: 977
# Loss Agent0:0.4970118999481201
#
#  Iteration: 978
# Loss Agent0:0.3870087265968323
#
#  Iteration: 979
# Loss Agent0:0.3982664942741394
#
#  Iteration: 980
# Loss Agent0:0.45900484919548035
#
#  Iteration: 981
# Loss Agent0:0.4233076572418213
#
#  Iteration: 982
# Loss Agent0:0.4629376530647278
#
#  Iteration: 983
# Loss Agent0:0.376169353723526
#
#  Iteration: 984
# Loss Agent0:0.46390897035598755
#
#  Iteration: 985
# Loss Agent0:0.40046772360801697
#
#  Iteration: 986
# Loss Agent0:0.351308137178421
#
#  Iteration: 987
# Loss Agent0:0.38109147548675537
#
#  Iteration: 988
# Loss Agent0:0.3676827847957611
#
#  Iteration: 989
# Loss Agent0:0.5629664063453674
#
#  Iteration: 990
# Loss Agent0:0.46980616450309753
#
#  Iteration: 991
# Loss Agent0:0.3764384984970093
#
#  Iteration: 992
# Loss Agent0:0.39851027727127075
#
#  Iteration: 993
# Loss Agent0:0.43116310238838196
#
#  Iteration: 994
# Loss Agent0:0.354805588722229
#
#  Iteration: 995
# Loss Agent0:0.3605095148086548
#
#  Iteration: 996
# Loss Agent0:0.43524688482284546
#
#  Iteration: 997
# Loss Agent0:0.46446284651756287
#
#  Iteration: 998
# Loss Agent0:0.43281304836273193
#
#  Iteration: 999
# Loss Agent0:0.351961225271225
#
#  Iteration: 1000
# Loss Agent0:0.38785696029663086
#
#  Iteration: 1001
# Loss Agent0:0.46205735206604004
#
#  Iteration: 1002
# Loss Agent0:0.45369473099708557
#
#  Iteration: 1003
# Loss Agent0:0.564839243888855
#
#  Iteration: 1004
# Loss Agent0:0.3781379461288452
#
#  Iteration: 1005
# Loss Agent0:0.3739532232284546
#
#  Iteration: 1006
# Loss Agent0:0.40408191084861755
#
#  Iteration: 1007
# Loss Agent0:0.5361791849136353
#
#  Iteration: 1008
# Loss Agent0:0.3077210783958435
#
#  Iteration: 1009
# Loss Agent0:0.40714263916015625
#
#  Iteration: 1010
# Loss Agent0:0.4420788288116455
#
#  Iteration: 1011
# Loss Agent0:0.45645105838775635
#
#  Iteration: 1012
# Loss Agent0:0.5306508541107178
#
#  Iteration: 1013
# Loss Agent0:0.40503764152526855
#
#  Iteration: 1014
# Loss Agent0:0.4737587869167328
#
#  Iteration: 1015
# Loss Agent0:0.4118826985359192
#
#  Iteration: 1016
# Loss Agent0:0.38193073868751526
#
#  Iteration: 1017
# Loss Agent0:0.45710447430610657
#
#  Iteration: 1018
# Loss Agent0:0.44011667370796204
#
#  Iteration: 1019
# Loss Agent0:0.4009254574775696
#
#  Iteration: 1020
# Loss Agent0:0.3483297526836395
#
#  Iteration: 1021
# Loss Agent0:0.33095622062683105
#
#  Iteration: 1022
# Loss Agent0:0.38754913210868835
#
#  Iteration: 1023
# Loss Agent0:0.3961305618286133
#
#  Iteration: 1024
# Loss Agent0:0.4704238176345825
#
#  Iteration: 1025
# Loss Agent0:0.42310333251953125
#
#  Iteration: 1026
# Loss Agent0:0.39825981855392456
#
#  Iteration: 1027
# Loss Agent0:0.4355323910713196
#
#  Iteration: 1028
# Loss Agent0:0.35331806540489197
#
#  Iteration: 1029
# Loss Agent0:0.4259493350982666
#
#  Iteration: 1030
# Loss Agent0:0.4006018340587616
#
#  Iteration: 1031
# Loss Agent0:0.5240569710731506
#
#  Iteration: 1032
# Loss Agent0:0.3390446603298187
#
#  Iteration: 1033
# Loss Agent0:0.42599356174468994
#
#  Iteration: 1034
# Loss Agent0:0.3681182265281677
#
#  Iteration: 1035
# Loss Agent0:0.2811165153980255
#
#  Iteration: 1036
# Loss Agent0:0.3632511794567108
#
#  Iteration: 1037
# Loss Agent0:0.4163382947444916
#
#  Iteration: 1038
# Loss Agent0:0.40468183159828186
#
#  Iteration: 1039
# Loss Agent0:0.4051913022994995
#
#  Iteration: 1040
# Loss Agent0:0.3589966595172882
#
#  Iteration: 1041
# Loss Agent0:0.4097624719142914
#
#  Iteration: 1042
# Loss Agent0:0.3357836902141571
#
#  Iteration: 1043
# Loss Agent0:0.4856630265712738
#
#  Iteration: 1044
# Loss Agent0:0.42880120873451233
#
#  Iteration: 1045
# Loss Agent0:0.3709335923194885
#
#  Iteration: 1046
# Loss Agent0:0.3082844614982605
#
#  Iteration: 1047
# Loss Agent0:0.30324339866638184
#
#  Iteration: 1048
# Loss Agent0:0.33550891280174255
#
#  Iteration: 1049
# Loss Agent0:0.40648865699768066
#
#  Iteration: 1050
# Loss Agent0:0.41308721899986267
#
#  Iteration: 1051
# Loss Agent0:0.4040980637073517
#
#  Iteration: 1052
# Loss Agent0:0.39095792174339294
#
#  Iteration: 1053
# Loss Agent0:0.34322309494018555
#
#  Iteration: 1054
# Loss Agent0:0.332624614238739
#
#  Iteration: 1055
# Loss Agent0:0.37604692578315735
#
#  Iteration: 1056
# Loss Agent0:0.38917481899261475
#
#  Iteration: 1057
# Loss Agent0:0.3977507948875427
#
#  Iteration: 1058
# Loss Agent0:0.3679673671722412
#
#  Iteration: 1059
# Loss Agent0:0.3734796643257141
#
#  Iteration: 1060
# Loss Agent0:0.4314294755458832
#
#  Iteration: 1061
# Loss Agent0:0.4008716344833374
#
#  Iteration: 1062
# Loss Agent0:0.4679657816886902
#
#  Iteration: 1063
# Loss Agent0:0.29489386081695557
#
#  Iteration: 1064
# Loss Agent0:0.41032302379608154
#
#  Iteration: 1065
# Loss Agent0:0.31554725766181946
#
#  Iteration: 1066
# Loss Agent0:0.338045597076416
#
#  Iteration: 1067
# Loss Agent0:0.43715590238571167
#
#  Iteration: 1068
# Loss Agent0:0.4199299216270447
#
#  Iteration: 1069
# Loss Agent0:0.3491339087486267
#
#  Iteration: 1070
# Loss Agent0:0.3414294421672821
#
#  Iteration: 1071
# Loss Agent0:0.431356281042099
#
#  Iteration: 1072
# Loss Agent0:0.3801746964454651
#
#  Iteration: 1073
# Loss Agent0:0.37674933671951294
#
#  Iteration: 1074
# Loss Agent0:0.44740280508995056
#
#  Iteration: 1075
# Loss Agent0:0.32136160135269165
#
#  Iteration: 1076
# Loss Agent0:0.27667590975761414
#
#  Iteration: 1077
# Loss Agent0:0.3825507164001465
#
#  Iteration: 1078
# Loss Agent0:0.43061625957489014
#
#  Iteration: 1079
# Loss Agent0:0.40985846519470215
#
#  Iteration: 1080
# Loss Agent0:0.33557555079460144
#
# ...
# Loss Agent0:0.3435450792312622
#
#  Iteration: 2254
# Loss Agent0:0.32544517517089844
#
#  Iteration: 2255
# Loss Agent0:0.24928495287895203
#
#  Iteration: 2256
# Loss Agent0:0.25403302907943726
#
#  Iteration: 2257
# Loss Agent0:0.32636213302612305
#
#  Iteration: 2258
# Loss Agent0:0.25323599576950073
#
#  Iteration: 2259
# Loss Agent0:0.2464752495288849
#
#  Iteration: 2260
# Loss Agent0:0.2631075084209442
#
#  Iteration: 2261
# Loss Agent0:0.3300459384918213
#
#  Iteration: 2262
# Loss Agent0:0.24227580428123474
#
#  Iteration: 2263
# Loss Agent0:0.29817020893096924
#
#  Iteration: 2264
# Loss Agent0:0.19208164513111115
#
#  Iteration: 2265
# Loss Agent0:0.3476319909095764
#
#  Iteration: 2266
# Loss Agent0:0.2186582088470459
#
#  Iteration: 2267
# Loss Agent0:0.23637503385543823
#
#  Iteration: 2268
# Loss Agent0:0.14959342777729034
#
#  Iteration: 2269
# Loss Agent0:0.2843855023384094
#
#  Iteration: 2270
# Loss Agent0:0.3624601364135742
#
#  Iteration: 2271
# Loss Agent0:0.3230481743812561
#
#  Iteration: 2272
# Loss Agent0:0.29793059825897217
#
#  Iteration: 2273
# Loss Agent0:0.3352029323577881
#
#  Iteration: 2274
# Loss Agent0:0.2352442741394043
#
#  Iteration: 2275
# Loss Agent0:0.302176833152771
#
#  Iteration: 2276
# Loss Agent0:0.19084201753139496
#
#  Iteration: 2277
# Loss Agent0:0.27344706654548645
#
#  Iteration: 2278
# Loss Agent0:0.23927800357341766
#
#  Iteration: 2279
# Loss Agent0:0.2574527859687805
#
#  Iteration: 2280
# Loss Agent0:0.26712822914123535
#
#  Iteration: 2281
# Loss Agent0:0.21300648152828217
#
#  Iteration: 2282
# Loss Agent0:0.23568862676620483
#
#  Iteration: 2283
# Loss Agent0:0.24606069922447205
#
#  Iteration: 2284
# Loss Agent0:0.2494981735944748
#
#  Iteration: 2285
# Loss Agent0:0.26195570826530457
#
#  Iteration: 2286
# Loss Agent0:0.3232119083404541
#
#  Iteration: 2287
# Loss Agent0:0.26743417978286743
#
#  Iteration: 2288
# Loss Agent0:0.3735412061214447
#
#  Iteration: 2289
# Loss Agent0:0.3106639087200165
#
#  Iteration: 2290
# Loss Agent0:0.18511787056922913
#
#  Iteration: 2291
# Loss Agent0:0.23684194684028625
#
#  Iteration: 2292
# Loss Agent0:0.2710237503051758
#
#  Iteration: 2293
# Loss Agent0:0.2289813607931137
#
#  Iteration: 2294
# Loss Agent0:0.31174787878990173
#
#  Iteration: 2295
# Loss Agent0:0.27112582325935364
#
#  Iteration: 2296
# Loss Agent0:0.2680164873600006
#
#  Iteration: 2297
# Loss Agent0:0.27139055728912354
#
#  Iteration: 2298
# Loss Agent0:0.23645912110805511
#
#  Iteration: 2299
# Loss Agent0:0.2991522550582886
#
#  Iteration: 2300
# Loss Agent0:0.2564041018486023
#
#  Iteration: 2301
# Loss Agent0:0.16153347492218018
#
#  Iteration: 2302
# Loss Agent0:0.3115208148956299
#
#  Iteration: 2303
# Loss Agent0:0.24282415211200714
#
#  Iteration: 2304
# Loss Agent0:0.25984084606170654
#
#  Iteration: 2305
# Loss Agent0:0.1798684448003769
#
#  Iteration: 2306
# Loss Agent0:0.272416353225708
#
#  Iteration: 2307
# Loss Agent0:0.33357182145118713
#
#  Iteration: 2308
# Loss Agent0:0.24316778779029846
#
#  Iteration: 2309
# Loss Agent0:0.2849087119102478
#
#  Iteration: 2310
# Loss Agent0:0.23007401823997498
#
#  Iteration: 2311
# Loss Agent0:0.2850646674633026
#
#  Iteration: 2312
# Loss Agent0:0.30267250537872314
#
#  Iteration: 2313
# Loss Agent0:0.26966002583503723
#
#  Iteration: 2314
# Loss Agent0:0.2340199500322342
#
#  Iteration: 2315
# Loss Agent0:0.3307810127735138
#
#  Iteration: 2316
# Loss Agent0:0.19404533505439758
#
#  Iteration: 2317
# Loss Agent0:0.16368165612220764
#
#  Iteration: 2318
# Loss Agent0:0.2846928536891937
#
#  Iteration: 2319
# Loss Agent0:0.2819959223270416
#
#  Iteration: 2320
# Loss Agent0:0.28553321957588196
#
#  Iteration: 2321
# Loss Agent0:0.3426187038421631
#
#  Iteration: 2322
# Loss Agent0:0.33317863941192627
#
#  Iteration: 2323
# Loss Agent0:0.25846803188323975
#
#  Iteration: 2324
# Loss Agent0:0.3259657025337219
#
#  Iteration: 2325
# Loss Agent0:0.32347989082336426
#
#  Iteration: 2326
# Loss Agent0:0.3238082826137543
#
#  Iteration: 2327
# Loss Agent0:0.22048553824424744
#
#  Iteration: 2328
# Loss Agent0:0.30735573172569275
#
#  Iteration: 2329
# Loss Agent0:0.3124789595603943
#
#  Iteration: 2330
# Loss Agent0:0.2485254406929016
#
#  Iteration: 2331
# Loss Agent0:0.26744145154953003
#
#  Iteration: 2332
# Loss Agent0:0.2328510284423828
#
#  Iteration: 2333
# Loss Agent0:0.27944135665893555
#
#  Iteration: 2334
# Loss Agent0:0.1818859875202179
#
#  Iteration: 2335
# Loss Agent0:0.3848663568496704
#
#  Iteration: 2336
# Loss Agent0:0.33149540424346924
#
#  Iteration: 2337
# Loss Agent0:0.33217957615852356
#
#  Iteration: 2338
# Loss Agent0:0.18129870295524597
#
#  Iteration: 2339
# Loss Agent0:0.1752113699913025
#
#  Iteration: 2340
# Loss Agent0:0.22295422852039337
#
#  Iteration: 2341
# Loss Agent0:0.31893032789230347
#
#  Iteration: 2342
# Loss Agent0:0.286081463098526
#
#  Iteration: 2343
# Loss Agent0:0.29450225830078125
#
#  Iteration: 2344
# Loss Agent0:0.2850055694580078
#
#  Iteration: 2345
# Loss Agent0:0.2747437357902527
#
#  Iteration: 2346
# Loss Agent0:0.30257320404052734
#
#  Iteration: 2347
# Loss Agent0:0.2544749975204468
#
#  Iteration: 2348
# Loss Agent0:0.3272671103477478
#
#  Iteration: 2349
# Loss Agent0:0.26513931155204773
#
#  Iteration: 2350
# Loss Agent0:0.2809286415576935
#
#  Iteration: 2351
# Loss Agent0:0.3143242597579956
#
#  Iteration: 2352
# Loss Agent0:0.37720221281051636
#
#  Iteration: 2353
# Loss Agent0:0.26319023966789246
#
#  Iteration: 2354
# Loss Agent0:0.2998793125152588
#
#  Iteration: 2355
# Loss Agent0:0.33455565571784973
#
#  Iteration: 2356
# Loss Agent0:0.21015861630439758
#
#  Iteration: 2357
# Loss Agent0:0.27675661444664
#
#  Iteration: 2358
# Loss Agent0:0.254372239112854
#
#  Iteration: 2359
# Loss Agent0:0.242449089884758
#
#  Iteration: 2360
# Loss Agent0:0.18903745710849762
#
#  Iteration: 2361
# Loss Agent0:0.2335030436515808
#
#  Iteration: 2362
# Loss Agent0:0.3287440538406372
#
#  Iteration: 2363
# Loss Agent0:0.30203381180763245
#
#  Iteration: 2364
# Loss Agent0:0.26438188552856445
#
#  Iteration: 2365
# Loss Agent0:0.23361407220363617
#
#  Iteration: 2366
# Loss Agent0:0.24902932345867157
#
#  Iteration: 2367
# Loss Agent0:0.25571340322494507
#
#  Iteration: 2368
# Loss Agent0:0.1746513992547989
#
#  Iteration: 2369
# Loss Agent0:0.3404444456100464
#
#  Iteration: 2370
# Loss Agent0:0.25402265787124634
#
#  Iteration: 2371
# Loss Agent0:0.33032721281051636
#
#  Iteration: 2372
# Loss Agent0:0.27084505558013916
#
#  Iteration: 2373
# Loss Agent0:0.2731843590736389
#
#  Iteration: 2374
# Loss Agent0:0.2982958257198334
#
#  Iteration: 2375
# Loss Agent0:0.2882963716983795
#
#  Iteration: 2376
# Loss Agent0:0.2440907210111618
#
#  Iteration: 2377
# Loss Agent0:0.2557884454727173
#
#  Iteration: 2378
# Loss Agent0:0.2544593811035156
#
#  Iteration: 2379
# Loss Agent0:0.32253119349479675
#
#  Iteration: 2380
# Loss Agent0:0.27296873927116394
#
#  Iteration: 2381
# Loss Agent0:0.21805265545845032
#
#  Iteration: 2382
# Loss Agent0:0.25440776348114014
#
#  Iteration: 2383
# Loss Agent0:0.23128946125507355
#
#  Iteration: 2384
# Loss Agent0:0.21665823459625244
#
#  Iteration: 2385
# Loss Agent0:0.3084227740764618
#
#  Iteration: 2386
# Loss Agent0:0.28866928815841675
#
#  Iteration: 2387
# Loss Agent0:0.20415127277374268
#
#  Iteration: 2388
# Loss Agent0:0.3262265622615814
#
#  Iteration: 2389
# Loss Agent0:0.32087835669517517
#
#  Iteration: 2390
# Loss Agent0:0.3033774495124817
#
#  Iteration: 2391
# Loss Agent0:0.2950499951839447
#
#  Iteration: 2392
# Loss Agent0:0.2925323247909546
#
#  Iteration: 2393
# Loss Agent0:0.2649669051170349
#
#  Iteration: 2394
# Loss Agent0:0.3683197796344757
#
#  Iteration: 2395
# Loss Agent0:0.15224941074848175
#
#  Iteration: 2396
# Loss Agent0:0.2743413746356964
#
#  Iteration: 2397
# Loss Agent0:0.279927134513855
#
#  Iteration: 2398
# Loss Agent0:0.31051090359687805
#
#  Iteration: 2399
# Loss Agent0:0.31500545144081116
#
#  Iteration: 2400
# Loss Agent0:0.25279560685157776
#
#  Iteration: 2401
# Loss Agent0:0.27235889434814453
#
#  Iteration: 2402
# Loss Agent0:0.3472268581390381
#
#  Iteration: 2403
# Loss Agent0:0.2345331907272339
#
#  Iteration: 2404
# Loss Agent0:0.2589937150478363
#
#  Iteration: 2405
# Loss Agent0:0.29197177290916443
#
#  Iteration: 2406
# Loss Agent0:0.30047672986984253
#
#  Iteration: 2407
# Loss Agent0:0.26055899262428284
#
#  Iteration: 2408
# Loss Agent0:0.20558103919029236
#
#  Iteration: 2409
# Loss Agent0:0.30627477169036865
#
#  Iteration: 2410
# Loss Agent0:0.2453615665435791
#
#  Iteration: 2411
# Loss Agent0:0.2591678500175476
#
#  Iteration: 2412
# Loss Agent0:0.17077898979187012
#
#  Iteration: 2413
# Loss Agent0:0.19976907968521118
#
#  Iteration: 2414
# Loss Agent0:0.27715229988098145
#
#  Iteration: 2415
# Loss Agent0:0.2383488416671753
#
#  Iteration: 2416
# Loss Agent0:0.2865584194660187
#
#  Iteration: 2417
# Loss Agent0:0.3821982145309448
#
#  Iteration: 2418
# Loss Agent0:0.23194697499275208
#
#  Iteration: 2419
# Loss Agent0:0.2381485402584076
#
#  Iteration: 2420
# Loss Agent0:0.21642594039440155
#
#  Iteration: 2421
# Loss Agent0:0.26497140526771545
#
#  Iteration: 2422
# Loss Agent0:0.27932971715927124
#
#  Iteration: 2423
# Loss Agent0:0.27839821577072144
#
#  Iteration: 2424
# Loss Agent0:0.1729428619146347
#
#  Iteration: 2425
# Loss Agent0:0.3236055076122284
#
#  Iteration: 2426
# Loss Agent0:0.2687040865421295
#
#  Iteration: 2427
# Loss Agent0:0.3093799650669098
#
#  Iteration: 2428
# Loss Agent0:0.2083478718996048
#
#  Iteration: 2429
# Loss Agent0:0.2147912085056305
#
#  Iteration: 2430
# Loss Agent0:0.3487406373023987
#
#  Iteration: 2431
# Loss Agent0:0.22114913165569305
#
#  Iteration: 2432
# Loss Agent0:0.22589975595474243
#
#  Iteration: 2433
# Loss Agent0:0.26230090856552124
#
#  Iteration: 2434
# Loss Agent0:0.21155360341072083
#
#  Iteration: 2435
# Loss Agent0:0.25103533267974854
#
#  Iteration: 2436
# Loss Agent0:0.2814358174800873
#
#  Iteration: 2437
# Loss Agent0:0.23154990375041962
#
#  Iteration: 2438
# Loss Agent0:0.27757665514945984
#
#  Iteration: 2439
# Loss Agent0:0.2827936112880707
#
#  Iteration: 2440
# Loss Agent0:0.22578567266464233
#
#  Iteration: 2441
# Loss Agent0:0.20442503690719604
#
#  Iteration: 2442
# Loss Agent0:0.27704307436943054
#
#  Iteration: 2443
# Loss Agent0:0.3064478039741516
#
#  Iteration: 2444
# Loss Agent0:0.30263862013816833
#
#  Iteration: 2445
# Loss Agent0:0.3096613883972168
#
#  Iteration: 2446
# Loss Agent0:0.2976076602935791
#
#  Iteration: 2447
# Loss Agent0:0.2805250883102417
#
#  Iteration: 2448
# Loss Agent0:0.22531923651695251
#
#  Iteration: 2449
# Loss Agent0:0.20599716901779175
#
#  Iteration: 2450
# Loss Agent0:0.3492291569709778
#
#  Iteration: 2451
# Loss Agent0:0.23700742423534393
#
#  Iteration: 2452
# Loss Agent0:0.2907378375530243
#
#  Iteration: 2453
# Loss Agent0:0.24045391380786896
#
#  Iteration: 2454
# Loss Agent0:0.2547678053379059
#
#  Iteration: 2455
# Loss Agent0:0.2689428925514221
#
#  Iteration: 2456
# Loss Agent0:0.25568875670433044
#
#  Iteration: 2457
# Loss Agent0:0.29310348629951477
#
#  Iteration: 2458
# Loss Agent0:0.24180597066879272
#
#  Iteration: 2459
# Loss Agent0:0.26841849088668823
#
#  Iteration: 2460
# Loss Agent0:0.24074707925319672
#
#  Iteration: 2461
# Loss Agent0:0.2557118237018585
#
#  Iteration: 2462
# Loss Agent0:0.25064781308174133
#
#  Iteration: 2463
# Loss Agent0:0.3208843469619751
#
#  Iteration: 2464
# Loss Agent0:0.24688148498535156
#
#  Iteration: 2465
# Loss Agent0:0.4142643213272095
#
#  Iteration: 2466
# Loss Agent0:0.2718692123889923
#
#  Iteration: 2467
# Loss Agent0:0.28888630867004395
#
#  Iteration: 2468
# Loss Agent0:0.3367435932159424
#
#  Iteration: 2469
# Loss Agent0:0.22491198778152466
#
#  Iteration: 2470
# Loss Agent0:0.23134541511535645
#
#  Iteration: 2471
# Loss Agent0:0.27992624044418335
#
#  Iteration: 2472
# Loss Agent0:0.2733413875102997
#
#  Iteration: 2473
# Loss Agent0:0.227237731218338
#
#  Iteration: 2474
# Loss Agent0:0.2306351661682129
#
#  Iteration: 2475
# Loss Agent0:0.23067249357700348
#
#  Iteration: 2476
# Loss Agent0:0.32164809107780457
#
#  Iteration: 2477
# Loss Agent0:0.236436128616333
#
#  Iteration: 2478
# Loss Agent0:0.3202202618122101
#
#  Iteration: 2479
# Loss Agent0:0.23175270855426788
#
#  Iteration: 2480
# Loss Agent0:0.3447442054748535
#
#  Iteration: 2481
# Loss Agent0:0.2707355320453644
#
#  Iteration: 2482
# Loss Agent0:0.21288220584392548
#
#  Iteration: 2483
# Loss Agent0:0.26292553544044495
#
#  Iteration: 2484
# Loss Agent0:0.20069025456905365
#
#  Iteration: 2485
# Loss Agent0:0.28617289662361145
#
#  Iteration: 2486
# Loss Agent0:0.26303669810295105
#
#  Iteration: 2487
# Loss Agent0:0.14068980515003204
#
#  Iteration: 2488
# Loss Agent0:0.2314930111169815
#
#  Iteration: 2489
# Loss Agent0:0.26645544171333313
#
#  Iteration: 2490
# Loss Agent0:0.332770437002182
#
#  Iteration: 2491
# Loss Agent0:0.2789582312107086
#
#  Iteration: 2492
# Loss Agent0:0.25612545013427734
#
#  Iteration: 2493
# Loss Agent0:0.21944034099578857
#
#  Iteration: 2494
# Loss Agent0:0.1733117699623108
#
#  Iteration: 2495
# Loss Agent0:0.31585052609443665
#
#  Iteration: 2496
# Loss Agent0:0.25017136335372925
#
#  Iteration: 2497
# Loss Agent0:0.24606984853744507
#
#  Iteration: 2498
# Loss Agent0:0.29289957880973816
#
#  Iteration: 2499
# Loss Agent0:0.2511632740497589
#
#  Iteration: 2500
# Loss Agent0:0.2830325961112976
#
#  Iteration: 2501
# Loss Agent0:0.23040223121643066
#
#  Iteration: 2502
# Loss Agent0:0.25221195816993713
#
#  Iteration: 2503
# Loss Agent0:0.2615390717983246
#
#  Iteration: 2504
# Loss Agent0:0.19988688826560974
#
#  Iteration: 2505
# Loss Agent0:0.20480354130268097
#
#  Iteration: 2506
# Loss Agent0:0.30931273102760315
#
#  Iteration: 2507
# Loss Agent0:0.27840328216552734
#
#  Iteration: 2508
# Loss Agent0:0.3254699110984802
#
#  Iteration: 2509
# Loss Agent0:0.31574541330337524
#
#  Iteration: 2510
# Loss Agent0:0.2613486647605896
#
#  Iteration: 2511
# Loss Agent0:0.23108923435211182
#
#  Iteration: 2512
# Loss Agent0:0.2306661307811737
#
#  Iteration: 2513
# Loss Agent0:0.2580260634422302
#
#  Iteration: 2514
# Loss Agent0:0.22171767055988312
#
#  Iteration: 2515
# Loss Agent0:0.2813972532749176
#
#  Iteration: 2516
# Loss Agent0:0.2702648341655731
#
#  Iteration: 2517
# Loss Agent0:0.24666330218315125
#
#  Iteration: 2518
# Loss Agent0:0.3332287669181824
#
#  Iteration: 2519
# Loss Agent0:0.219514861702919
#
#  Iteration: 2520
# Loss Agent0:0.198480486869812
#
#  Iteration: 2521
# Loss Agent0:0.29108744859695435
#
#  Iteration: 2522
# Loss Agent0:0.26364076137542725
#
#  Iteration: 2523
# Loss Agent0:0.16780227422714233
#
#  Iteration: 2524
# Loss Agent0:0.24719545245170593
#
#  Iteration: 2525
# Loss Agent0:0.23832274973392487
#
#  Iteration: 2526
# Loss Agent0:0.2547018229961395
#
#  Iteration: 2527
# Loss Agent0:0.34168899059295654
#
#  Iteration: 2528
# Loss Agent0:0.13991834223270416
#
#  Iteration: 2529
# Loss Agent0:0.2849113941192627
#
#  Iteration: 2530
# Loss Agent0:0.2768217921257019
#
#  Iteration: 2531
# Loss Agent0:0.29569166898727417
#
#  Iteration: 2532
# Loss Agent0:0.18767385184764862
#
#  Iteration: 2533
# Loss Agent0:0.33015865087509155
#
#  Iteration: 2534
# Loss Agent0:0.27139368653297424
#
#  Iteration: 2535
# Loss Agent0:0.24002715945243835
#
#  Iteration: 2536
# Loss Agent0:0.2426033318042755
#
#  Iteration: 2537
# Loss Agent0:0.28748056292533875
#
#  Iteration: 2538
# Loss Agent0:0.19587121903896332
#
#  Iteration: 2539
# Loss Agent0:0.18055590987205505
#
#  Iteration: 2540
# Loss Agent0:0.33838793635368347
#
#  Iteration: 2541
# Loss Agent0:0.20172721147537231
#
#  Iteration: 2542
# Loss Agent0:0.2359369993209839
#
#  Iteration: 2543
# Loss Agent0:0.3545389175415039
#
#  Iteration: 2544
# Loss Agent0:0.26985493302345276
#
#  Iteration: 2545
# Loss Agent0:0.22877930104732513
#
#  Iteration: 2546
# Loss Agent0:0.27146369218826294
#
#  Iteration: 2547
# Loss Agent0:0.32442426681518555
#
#  Iteration: 2548
# Loss Agent0:0.2587367594242096
#
#  Iteration: 2549
# Loss Agent0:0.30535686016082764
#
#  Iteration: 2550
# Loss Agent0:0.22498521208763123
#
#  Iteration: 2551
# Loss Agent0:0.270531564950943
#
#  Iteration: 2552
# Loss Agent0:0.25264984369277954
#
#  Iteration: 2553
# Loss Agent0:0.30150866508483887
#
#  Iteration: 2554
# Loss Agent0:0.21584489941596985
#
#  Iteration: 2555
# Loss Agent0:0.2741330862045288
#
#  Iteration: 2556
# Loss Agent0:0.19246259331703186
#
#  Iteration: 2557
# Loss Agent0:0.27911192178726196
#
#  Iteration: 2558
# Loss Agent0:0.24499785900115967
#
#  Iteration: 2559
# Loss Agent0:0.2667424976825714
#
#  Iteration: 2560
# Loss Agent0:0.2647593021392822
#
#  Iteration: 2561
# Loss Agent0:0.3771205246448517
#
#  Iteration: 2562
# Loss Agent0:0.33844050765037537
#
#  Iteration: 2563
# Loss Agent0:0.25693774223327637
#
#  Iteration: 2564
# Loss Agent0:0.20034365355968475
#
#  Iteration: 2565
# Loss Agent0:0.26381057500839233
#
#  Iteration: 2566
# Loss Agent0:0.33233463764190674
#
#  Iteration: 2567
# Loss Agent0:0.2995957136154175
#
#  Iteration: 2568
# Loss Agent0:0.19916659593582153
#
#  Iteration: 2569
# Loss Agent0:0.3355500102043152
#
#  Iteration: 2570
# Loss Agent0:0.24033589661121368
#
#  Iteration: 2571
# Loss Agent0:0.20921674370765686
#
#  Iteration: 2572
# Loss Agent0:0.17758822441101074
#
#  Iteration: 2573
# Loss Agent0:0.2018444836139679
#
#  Iteration: 2574
# Loss Agent0:0.22746960818767548
#
#  Iteration: 2575
# Loss Agent0:0.20022810995578766
#
#  Iteration: 2576

# %% [markdown]
# ### Evaluate Networks (Convergence and Value of states)

# %%
state = torch.tensor(int(0),dtype=torch.float32).unsqueeze(0)
policy_net1(state), target_net1(state)

# %%
state = torch.tensor(int(1),dtype=torch.float32).unsqueeze(0)
policy_net1(state), target_net1(state)

# %% [markdown]
# ### Trace Path

# %%
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

def plot(actions, title):
    plt.plot(moving_average(actions[:,0],100), label = 'Agent 1 Actions', marker = 'o', c = 'b')
    plt.plot(moving_average(actions[:,1],100), label = 'Agent 2 Actions', marker = 'x', c = 'r')
    plt.title(title)

# %%
actions = np.array(actions)
plot(actions, 'Learning againg C only')

# %%
actions = np.array(actions)
plot(actions, 'Learning againg D only')

# %%
actions = np.array(actions)
plot(actions, 'Learning against Tit-for-Tat only')
