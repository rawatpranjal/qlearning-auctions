# %% [markdown]
# ### Cournot Duopoly
#
# - There are two firms that interact in repeated Cournot duopoly game.
# - Costs: c1,c2
# - Demand: P = 1-Q
# - Benchmarks: Competition/Nash Price and Quantities and Monopoly Price and Quantity

# %% [markdown]
# ### Packages

# %%
from itertools import count
import torch
import math
import torch.optim as optim 
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (30, 10)
plt.rcParams['font.size']=20
import numpy as np
np.set_printoptions(precision=3)

# %% [markdown]
# ### Cournot Game

# %%
def P(Q):
    return max(1-Q,0)
    
class firm:
    def __init__(self, c):
        self.c = c
    
    def profit(self,p,q):
        return (p-self.c)*q
    
    def bestresponse(self, q_other):
        return (1-q_other-self.c)/2 
    
def profit(q1,q2):
    return (P(q1+q2)-c1)*q1,(P(q1+q2)-c2)*q2

def competition(c1,c2):
    q1c = (1+c2-2*c1)/3
    q2c = (1+c1-2*c2)/3
    Qc = q1c + q2c
    Pc = P(Qc)
    return q1c, q2c, Pc, Qc

def monopoly(c1,c2):
    if c1<c2:
        Qm = (1-c1)/2
        Pm = (1+c1)/2
    if c1<=c2:
        Qm = (1-c2)/2
        Pm = (1+c2)/2
    return Qm,Pm

def gameReward(q1,q2):
    Q = q1 + q2
    p = P(Q)
    π1 = firm1.profit(p,q1)
    π2 = firm2.profit(p,q2)
    return (π1,π2)

def generateGame(c1, c2):
    firm1 = firm(c1)
    firm2 = firm(c2)
    q1c, q2c, Pc, Qc = competition(c1,c2)
    print('Competition', Qc, Pc)
    Qm,Pm = monopoly(c1,c2)
    print('Monopoly', Qm, Pm)
    return q1c, q2c, Pc, Qc, Qm, Qc

# %%
c1, c2 = 0.1,0.1
firm1 = firm(c1)
firm2 = firm(c2)
q1c, q2c, Pc, Qc = competition(c1,c2)
Qm,Pm = monopoly(c1,c2)
Qgrid = np.linspace(0,Qc,10)
print(Qm,Qc, Qgrid)
# Out:
# 0.45 0.6000000000000001 [0.    0.067 0.133 0.2   0.267 0.333 0.4   0.467 0.533 0.6  ]

# %%
firm1.profit(Pc,q1c), firm2.profit(Pc,q2c)
# Out:
# (0.09, 0.09)

# %%
def gameReward(q1,q2):
    Q = q1 + q2
    p = P(Q)
    π1 = firm1.profit(p,q1)
    π2 = firm2.profit(p,q2)
    return (π1,π2)

# %% [markdown]
# ### Memory, Q-Network

# %%
import random
from collections import namedtuple, deque
Transition = namedtuple('Transition',('state','next_state','a1','a2','r1','r2'))

class ReplayMemory(object):
    # Holds transitions from experience and gives a random batch of transitions for training
    def __init__(self,capacity):
        self.memory = deque([], maxlen=capacity)
        
    def push(self,*args):
        "save transition"
        self.memory.append(Transition(*args))
        
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

class DQN(nn.Module):
    # Input: State
    # Output: 0,1
    # Network is going to try to predict the expected Return of taking each action given the INPUT
    def __init__(self, n_obs, n_actions):
        super(DQN,self).__init__()
        self.layer1 = nn.Linear(n_obs, 128)
        self.layer2 = nn.Linear(128,128)
        self.layer3 = nn.Linear(128, n_actions)
    
    def forward(self,x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)   

def select_action(state, policy_net, idx, n_actions):
    # Given state selects action either from the DQN or randomly. 
    global steps_done1, steps_done2
    sample = random.random()
    if idx == 0:
        eps_threshold = EPS_END + (EPS_START-EPS_END)*math.exp(-1.*steps_done1/EPS_DECAY)
        steps_done1 += 1
    else:
        eps_threshold = EPS_END + (EPS_START-EPS_END)*math.exp(-1.*steps_done2/EPS_DECAY)
        steps_done2 += 1
    
    if sample>eps_threshold:
        with torch.no_grad():
            try: 
                return policy_net(state).max(1)[1].view(1,1) # pick up action with largest expected reward
            except:
                return policy_net(state).max(0)[1].view(1,1) # pick up action with largest expected reward
    else:
        randchoice = random.choice(list(range(n_actions)))
        return torch.tensor([[randchoice]],dtype=torch.long)
    
def update_target_net(target_net, policy_net):
    target_net_state_dict = target_net.state_dict()
    policy_net_state_dict = policy_net.state_dict()
    for key in policy_net_state_dict:
        target_net_state_dict[key] = policy_net_state_dict[key]*TAU+target_net_state_dict[key]*(1-TAU)
    target_net.load_state_dict(target_net_state_dict)

def optimize_model(policy_net,target_net,idx):
    if len(memory)<BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions))
    
    # final state is after simulation is done
    # these are the "s(t+1)" from the transitions
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None, batch.next_state)),dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
    
    # we begin with a batch of transitions - (state, action, reward)
    state_batch = torch.cat(batch.state)
    if idx == 0:
        action_batch = torch.cat(batch.a1)
        reward_batch = torch.cat(batch.r1)
    elif idx == 1:
        action_batch = torch.cat(batch.a2)
        reward_batch = torch.cat(batch.r2)
    
    # For these batch states we compute optimal policy according to our policy-network
    # Compute Q(s,a) and get actions - these are the actions that would have been taken for each batch state 
    state_action_values = policy_net(state_batch.reshape(-1,1)).gather(1,action_batch)
    
    # Compute V(s_t+1)
    next_state_values = torch.zeros(BATCH_SIZE)
    with torch.no_grad():
        # Use the "old" target_net to obtain value (Expected Return) on optimal actions from sampled s(t+1)
        # This is Q_old(s',a')
        next_state_values[non_final_mask] = target_net(non_final_next_states.reshape(-1,1)).max(1)[0]
        
    # Here we have add r + max Q_old(s',a')
    expected_state_action_values = (next_state_values*GAMMA)+reward_batch

    # Compute the loss
    # Q_new(s,a) - r + max Q_old(s',a'): is the error
    # Huber loss function
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values,expected_state_action_values.unsqueeze(1))
    if idx == 0:
        optimizer1.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_value_(policy_net1.parameters(),100)
        optimizer1.step()
    elif idx == 1:
        optimizer2.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_value_(policy_net2.parameters(),100)
        optimizer2.step()
    print(f'Loss Agent{idx}:{loss.item()}')

# %% [markdown]
# ### Hyperparameters

# %%
BATCH_SIZE = 128 # number of transitions sampled from replay buffer
GAMMA = 0 # Discount factor
EPS_START = 0.9 # Initial value of Epsilon
EPS_END = 0.05 # End value of Epsilon
EPS_DECAY = 1000 # controls decay rate of Epsilon
TAU = 0.01 # update rate of target network
LR = 1e-3 # Learning rate of Adam

n_obs = 1 # size of memory
n_actions = 10 # action space
c1, c2 = 0.1,0.1
q1c, q2c, Pc, Qc, Qm, Qc = generateGame(c1, c2)
Qgrid = np.linspace(0,q1c,n_actions)
print(Qgrid)

policy_net1 = DQN(n_obs,n_actions)
target_net1 = DQN(n_obs,n_actions)
policy_net2 = DQN(n_obs,n_actions)
target_net2 = DQN(n_obs,n_actions)
steps_done1 = 0
steps_done2 = 0
optimizer1 = optim.AdamW(policy_net1.parameters(),lr=LR,amsgrad=True)
optimizer2 = optim.AdamW(policy_net2.parameters(),lr=LR,amsgrad=True)
memory=ReplayMemory(10000)
# Out:
# Competition 0.6000000000000001 0.3999999999999999
# Monopoly 0.45 0.55
# [0.    0.033 0.067 0.1   0.133 0.167 0.2   0.233 0.267 0.3  ]

# %%
state = torch.tensor(1,dtype=torch.float32).unsqueeze(0)
actions = []
prices = []
quantities = []
epochs = 5000
for t in range(epochs):
    print('\n Iteration:',t)
    # Take action
    a1 = select_action(state, policy_net1, 0, n_actions)
    a2 = select_action(state, policy_net2, 1, n_actions)
    print(a1,a2)
    # Obtain Rewards
    r1, r2 = gameReward(Qgrid[a1],Qgrid[a2])
    r1 = torch.tensor([r1])
    r2 = torch.tensor([r2])

    # Compute next state
    next_state = torch.tensor(1,dtype=torch.float32).unsqueeze(0)

    # store memory in transition
    memory.push(state,next_state,a1,a2,r1,r2)

    # move to next state
    state = next_state

    # optimize
    optimize_model(policy_net1,target_net1, 0)
    optimize_model(policy_net2,target_net2, 1)

    # soft update target_net
    update_target_net(target_net1, policy_net1)
    update_target_net(target_net2, policy_net2)
    
    # record actions
    actions.append([a1.item(),a2.item()])
    prices.append(P(a1.item()+a2.item()))
    quantities.append(1-P(a1.item()+a2.item()))
# Out:
#  Iteration: 0
# tensor([[1]]) tensor([[8]])
#
#  Iteration: 1
# tensor([[1]]) tensor([[7]])
#
#  Iteration: 2
# tensor([[4]]) tensor([[1]])
#
#  Iteration: 3
# tensor([[6]]) tensor([[9]])
#
#  Iteration: 4
# tensor([[3]]) tensor([[4]])
#
#  Iteration: 5
# tensor([[9]]) tensor([[6]])
#
#  Iteration: 6
# tensor([[6]]) tensor([[4]])
#
#  Iteration: 7
# tensor([[2]]) tensor([[3]])
#
#  Iteration: 8
# tensor([[1]]) tensor([[3]])
#
#  Iteration: 9
# tensor([[4]]) tensor([[3]])
#
#  Iteration: 10
# tensor([[3]]) tensor([[8]])
#
#  Iteration: 11
# tensor([[2]]) tensor([[4]])
#
#  Iteration: 12
# tensor([[9]]) tensor([[8]])
#
#  Iteration: 13
# tensor([[1]]) tensor([[2]])
#
#  Iteration: 14
# tensor([[5]]) tensor([[1]])
#
#  Iteration: 15
# tensor([[0]]) tensor([[8]])
#
#  Iteration: 16
# tensor([[5]]) tensor([[6]])
#
#  Iteration: 17
# tensor([[2]]) tensor([[3]])
#
#  Iteration: 18
# tensor([[9]]) tensor([[1]])
#
#  Iteration: 19
# tensor([[7]]) tensor([[0]])
#
#  Iteration: 20
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 21
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 22
# tensor([[5]]) tensor([[0]])
#
#  Iteration: 23
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 24
# tensor([[3]]) tensor([[7]])
#
#  Iteration: 25
# tensor([[3]]) tensor([[1]])
#
#  Iteration: 26
# tensor([[0]]) tensor([[1]])
#
#  Iteration: 27
# tensor([[0]]) tensor([[7]])
#
#  Iteration: 28
# tensor([[2]]) tensor([[1]])
#
#  Iteration: 29
# tensor([[1]]) tensor([[5]])
#
#  Iteration: 30
# tensor([[5]]) tensor([[4]])
#
#  Iteration: 31
# tensor([[0]]) tensor([[6]])
#
#  Iteration: 32
# tensor([[1]]) tensor([[7]])
#
#  Iteration: 33
# tensor([[1]]) tensor([[7]])
#
#  Iteration: 34
# tensor([[6]]) tensor([[2]])
#
#  Iteration: 35
# tensor([[3]]) tensor([[9]])
#
#  Iteration: 36
# tensor([[0]]) tensor([[7]])
#
#  Iteration: 37
# tensor([[3]]) tensor([[1]])
#
#  Iteration: 38
# tensor([[4]]) tensor([[1]])
#
#  Iteration: 39
# tensor([[1]]) tensor([[4]])
#
#  Iteration: 40
# tensor([[7]]) tensor([[4]])
#
#  Iteration: 41
# tensor([[2]]) tensor([[9]])
#
#  Iteration: 42
# tensor([[2]]) tensor([[0]])
#
#  Iteration: 43
# tensor([[8]]) tensor([[3]])
#
#  Iteration: 44
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 45
# tensor([[9]]) tensor([[0]])
#
#  Iteration: 46
# tensor([[3]]) tensor([[1]])
#
#  Iteration: 47
# tensor([[2]]) tensor([[1]])
#
#  Iteration: 48
# tensor([[5]]) tensor([[7]])
#
#  Iteration: 49
# tensor([[0]]) tensor([[1]])
#
#  Iteration: 50
# tensor([[8]]) tensor([[2]])
#
#  Iteration: 51
# tensor([[8]]) tensor([[7]])
#
#  Iteration: 52
# tensor([[5]]) tensor([[8]])
#
#  Iteration: 53
# tensor([[1]]) tensor([[6]])
#
#  Iteration: 54
# tensor([[5]]) tensor([[4]])
#
#  Iteration: 55
# tensor([[4]]) tensor([[1]])
#
#  Iteration: 56
# tensor([[1]]) tensor([[4]])
#
#  Iteration: 57
# tensor([[6]]) tensor([[4]])
#
#  Iteration: 58
# tensor([[9]]) tensor([[1]])
#
#  Iteration: 59
# tensor([[0]]) tensor([[8]])
#
#  Iteration: 60
# tensor([[6]]) tensor([[4]])
#
#  Iteration: 61
# tensor([[1]]) tensor([[2]])
#
#  Iteration: 62
# tensor([[9]]) tensor([[1]])
#
#  Iteration: 63
# tensor([[6]]) tensor([[7]])
#
#  Iteration: 64
# tensor([[8]]) tensor([[2]])
#
#  Iteration: 65
# tensor([[2]]) tensor([[1]])
#
#  Iteration: 66
# tensor([[3]]) tensor([[2]])
#
#  Iteration: 67
# tensor([[6]]) tensor([[9]])
#
#  Iteration: 68
# tensor([[5]]) tensor([[9]])
#
#  Iteration: 69
# tensor([[6]]) tensor([[9]])
#
#  Iteration: 70
# tensor([[6]]) tensor([[1]])
#
#  Iteration: 71
# tensor([[2]]) tensor([[3]])
#
#  Iteration: 72
# tensor([[5]]) tensor([[0]])
#
#  Iteration: 73
# tensor([[0]]) tensor([[1]])
#
#  Iteration: 74
# tensor([[8]]) tensor([[7]])
#
#  Iteration: 75
# tensor([[9]]) tensor([[9]])
#
#  Iteration: 76
# tensor([[1]]) tensor([[4]])
#
#  Iteration: 77
# tensor([[3]]) tensor([[1]])
#
#  Iteration: 78
# tensor([[1]]) tensor([[4]])
#
#  Iteration: 79
# tensor([[1]]) tensor([[2]])
#
#  Iteration: 80
# tensor([[8]]) tensor([[7]])
#
#  Iteration: 81
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 82
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 83
# tensor([[1]]) tensor([[9]])
#
#  Iteration: 84
# tensor([[9]]) tensor([[7]])
#
#  Iteration: 85
# tensor([[4]]) tensor([[1]])
#
#  Iteration: 86
# tensor([[4]]) tensor([[0]])
#
#  Iteration: 87
# tensor([[0]]) tensor([[1]])
#
#  Iteration: 88
# tensor([[3]]) tensor([[9]])
#
#  Iteration: 89
# tensor([[5]]) tensor([[6]])
#
#  Iteration: 90
# tensor([[8]]) tensor([[1]])
#
#  Iteration: 91
# tensor([[9]]) tensor([[2]])
#
#  Iteration: 92
# tensor([[9]]) tensor([[5]])
#
#  Iteration: 93
# tensor([[9]]) tensor([[6]])
#
#  Iteration: 94
# tensor([[1]]) tensor([[2]])
#
#  Iteration: 95
# tensor([[1]]) tensor([[0]])
#
#  Iteration: 96
# tensor([[5]]) tensor([[9]])
#
#  Iteration: 97
# tensor([[1]]) tensor([[4]])
#
#  Iteration: 98
# tensor([[5]]) tensor([[7]])
#
#  Iteration: 99
# tensor([[0]]) tensor([[0]])
#
#  Iteration: 100
# tensor([[0]]) tensor([[7]])
#
#  Iteration: 101
# tensor([[2]]) tensor([[9]])
#
#  Iteration: 102
# tensor([[7]]) tensor([[5]])
#
#  Iteration: 103
# tensor([[7]]) tensor([[1]])
#
#  Iteration: 104
# tensor([[8]]) tensor([[5]])
#
#  Iteration: 105
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 106
# tensor([[6]]) tensor([[7]])
#
#  Iteration: 107
# tensor([[0]]) tensor([[9]])
#
#  Iteration: 108
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 109
# tensor([[3]]) tensor([[4]])
#
#  Iteration: 110
# tensor([[2]]) tensor([[2]])
#
#  Iteration: 111
# tensor([[9]]) tensor([[5]])
#
#  Iteration: 112
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 113
# tensor([[7]]) tensor([[4]])
#
#  Iteration: 114
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 115
# tensor([[1]]) tensor([[8]])
#
#  Iteration: 116
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 117
# tensor([[8]]) tensor([[0]])
#
#  Iteration: 118
# tensor([[1]]) tensor([[0]])
#
#  Iteration: 119
# tensor([[1]]) tensor([[2]])
#
#  Iteration: 120
# tensor([[6]]) tensor([[1]])
#
#  Iteration: 121
# tensor([[1]]) tensor([[5]])
#
#  Iteration: 122
# tensor([[1]]) tensor([[8]])
#
#  Iteration: 123
# tensor([[1]]) tensor([[1]])
#
#  Iteration: 124
# tensor([[0]]) tensor([[3]])
#
#  Iteration: 125
# tensor([[2]]) tensor([[1]])
#
#  Iteration: 126
# tensor([[6]]) tensor([[4]])
#
#  Iteration: 127
# tensor([[7]]) tensor([[1]])
# Loss Agent0:0.010716929201750915
# Loss Agent1:0.029576782586492815
#
#  Iteration: 128
# tensor([[8]]) tensor([[4]])
# Loss Agent0:0.0035964613532433647
# Loss Agent1:0.016073456606702882
#
#  Iteration: 129
# tensor([[1]]) tensor([[4]])
# Loss Agent0:0.0007965031445612566
# Loss Agent1:0.008015848835156096
#
#  Iteration: 130
# tensor([[9]]) tensor([[2]])
# Loss Agent0:0.0007645373024742676
# Loss Agent1:0.003928346510574474
#
#  Iteration: 131
# tensor([[9]]) tensor([[7]])
# Loss Agent0:0.0014824736516543774
# Loss Agent1:0.002372931868352244
#
#  Iteration: 132
# tensor([[5]]) tensor([[6]])
# Loss Agent0:0.002020711404342409
# Loss Agent1:0.0022258881715610914
#
#  Iteration: 133
# tensor([[5]]) tensor([[6]])
# Loss Agent0:0.0018501912549758117
# Loss Agent1:0.002626151268270192
#
#  Iteration: 134
# tensor([[8]]) tensor([[9]])
# Loss Agent0:0.
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.00021379069815364668
# Loss Agent1:0.00018772970272018904
#
#  Iteration: 302
# tensor([[8]]) tensor([[7]])
# Loss Agent0:0.00020653920468746
# Loss Agent1:0.00017393363802223536
#
#  Iteration: 303
# tensor([[8]]) tensor([[4]])
# Loss Agent0:0.0001702888823573817
# Loss Agent1:0.00021017683391758658
#
#  Iteration: 304
# tensor([[9]]) tensor([[0]])
# Loss Agent0:0.000187895459862246
# Loss Agent1:0.0002122238094020797
#
#  Iteration: 305
# tensor([[1]]) tensor([[6]])
# Loss Agent0:0.0001977193613030406
# Loss Agent1:0.00021809999116526312
#
#  Iteration: 306
# tensor([[6]]) tensor([[9]])
# Loss Agent0:0.0002131460626981759
# Loss Agent1:0.0002064964484003747
#
#  Iteration: 307
# tensor([[9]]) tensor([[8]])
# Loss Agent0:0.00024366919745166734
# Loss Agent1:0.00016669570380758729
#
#  Iteration: 308
# tensor([[2]]) tensor([[4]])
# Loss Agent0:0.00021606337324360763
# Loss Agent1:0.00016928756975674388
#
#  Iteration: 309
# tensor([[9]]) tensor([[7]])
# Loss Agent0:0.00017342878098460754
# Loss Agent1:0.00019384773524978632
#
#  Iteration: 310
# tensor([[2]]) tensor([[9]])
# Loss Agent0:0.00017072534720724556
# Loss Agent1:0.00018766676085802767
#
#  Iteration: 311
# tensor([[7]]) tensor([[8]])
# Loss Agent0:0.00023703994850976198
# Loss Agent1:0.00018927772473829098
#
#  Iteration: 312
# tensor([[1]]) tensor([[3]])
# Loss Agent0:0.0002446904848142832
# Loss Agent1:0.00018462223981944575
#
#  Iteration: 313
# tensor([[6]]) tensor([[7]])
# Loss Agent0:0.00017923556750303187
# Loss Agent1:0.00021113378097839322
#
#  Iteration: 314
# tensor([[7]]) tensor([[9]])
# Loss Agent0:0.0001901994681517059
# Loss Agent1:0.0002091627378529142
#
#  Iteration: 315
# tensor([[2]]) tensor([[4]])
# Loss Agent0:0.00019999031638135537
# Loss Agent1:0.00020192280275261638
#
#  Iteration: 316
# tensor([[4]]) tensor([[0]])
# Loss Agent0:0.00020872800499962673
# Loss Agent1:0.0002546336991019356
#
#  Iteration: 317
# tensor([[9]]) tensor([[1]])
# Loss Agent0:0.000234723713825225
# Loss Agent1:0.0001928654882276396
#
#  Iteration: 318
# tensor([[8]]) tensor([[1]])
# Loss Agent0:0.0002178168831595969
# Loss Agent1:0.0001927430188517436
#
#  Iteration: 319
# tensor([[8]]) tensor([[8]])
# Loss Agent0:0.00019979738761792843
# Loss Agent1:0.0002320827500700816
#
#  Iteration: 320
# tensor([[6]]) tensor([[0]])
# Loss Agent0:0.00018071607367263503
# Loss Agent1:0.0002138649106861468
#
#  Iteration: 321
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.00022213747653101717
# Loss Agent1:0.0001810812620265903
#
#  Iteration: 322
# tensor([[8]]) tensor([[8]])
# Loss Agent0:0.00020197577711675014
# Loss Agent1:0.00019738279968455297
#
#  Iteration: 323
# tensor([[9]]) tensor([[8]])
# Loss Agent0:0.00023492254405142981
# Loss Agent1:0.0002289478040928869
#
#  Iteration: 324
# tensor([[9]]) tensor([[0]])
# Loss Agent0:0.00020029489186931308
# Loss Agent1:0.00022562291826942467
#
#  Iteration: 325
# tensor([[2]]) tensor([[8]])
# Loss Agent0:0.00021362614780176808
# Loss Agent1:0.00023115136736582306
#
#  Iteration: 326
# tensor([[2]]) tensor([[1]])
# Loss Agent0:0.0001971382316116891
# Loss Agent1:0.0001920136244551703
#
#  Iteration: 327
# tensor([[5]]) tensor([[9]])
# Loss Agent0:0.
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.00028302739153654487
# Loss Agent1:0.00030351282878681785
#
#  Iteration: 1338
# tensor([[3]]) tensor([[9]])
# Loss Agent0:0.0002512287319709547
# Loss Agent1:0.0002905114706785617
#
#  Iteration: 1339
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.0002630980520987185
# Loss Agent1:0.00030603220815440715
#
#  Iteration: 1340
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.0003129847317526292
# Loss Agent1:0.0002477586015197725
#
#  Iteration: 1341
# tensor([[9]]) tensor([[6]])
# Loss Agent0:0.00027399265253568367
# Loss Agent1:0.00033707417454921794
#
#  Iteration: 1342
# tensor([[9]]) tensor([[1]])
# Loss Agent0:0.00023254624942244839
# Loss Agent1:0.00026666355535741467
#
#  Iteration: 1343
# tensor([[1]]) tensor([[6]])
# Loss Agent0:0.0002305142783570535
# Loss Agent1:0.0002505944958338947
#
#  Iteration: 1344
# tensor([[3]]) tensor([[2]])
# Loss Agent0:0.00022381449493823658
# Loss Agent1:0.00032755360924066347
#
#  Iteration: 1345
# tensor([[7]]) tensor([[8]])
# Loss Agent0:0.00026870336509278686
# Loss Agent1:0.0002448160582251167
#
#  Iteration: 1346
# tensor([[8]]) tensor([[9]])
# Loss Agent0:0.0002743041054317821
# Loss Agent1:0.000227130151779723
#
#  Iteration: 1347
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.00022692788170629495
# Loss Agent1:0.00022669194931864426
#
#  Iteration: 1348
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.00026372747512698355
# Loss Agent1:0.00027527992443200937
#
#  Iteration: 1349
# tensor([[2]]) tensor([[7]])
# Loss Agent0:0.0002600479220164314
# Loss Agent1:0.00022058773508749395
#
#  Iteration: 1350
# tensor([[8]]) tensor([[9]])
# Loss Agent0:0.00025562873310449013
# Loss Agent1:0.0001857197512486134
#
#  Iteration: 1351
# tensor([[8]]) tensor([[9]])
# Loss Agent0:0.0003118532374578997
# Loss Agent1:0.000248249989693146
#
#  Iteration: 1352
# tensor([[8]]) tensor([[8]])
# Loss Agent0:0.00018359953946725787
# Loss Agent1:0.00027066296737007897
#
#  Iteration: 1353
# tensor([[8]]) tensor([[8]])
# Loss Agent0:0.00029519745868159604
# Loss Agent1:0.00019589205003606608
#
#  Iteration: 1354
# tensor([[0]]) tensor([[4]])
# Loss Agent0:0.0003048154033152327
# Loss Agent1:0.00021474342067562317
#
#  Iteration: 1355
# tensor([[4]]) tensor([[8]])
# Loss Agent0:0.00025771105827543215
# Loss Agent1:0.00032816153224225937
#
#  Iteration: 1356
# tensor([[8]]) tensor([[8]])
# Loss Agent0:0.0002743913634749599
# Loss Agent1:0.00022750006120297831
#
#  Iteration: 1357
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.000326512429002842
# Loss Agent1:0.00023717392177876695
#
#  Iteration: 1358
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.0003285458974138732
# Loss Agent1:0.0002484811046863885
#
#  Iteration: 1359
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.0002741647058048866
# Loss Agent1:0.0002992457373265159
#
#  Iteration: 1360
# tensor([[4]]) tensor([[9]])
# Loss Agent0:0.0002465560152673724
# Loss Agent1:0.00024484391175591633
#
#  Iteration: 1361
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.0002686087729737286
# Loss Agent1:0.00023413743416546997
#
#  Iteration: 1362
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.00035793097395898736
# Loss Agent1:0.00023193317248832246
#
#  Iteration: 1363
# tensor([[5]]) tensor([[2]])
# Loss Agent0:0.00020606724179139587
# Loss Agent1:0.00021272433686223436
#
#  Iteration: 1364
# tensor([[0]]) tensor([[8]])
# Loss Agent0:0.000318934762536203
# Loss Agent1:0.00032530558190829864
#
#  Iteration: 1365
# tensor([[9]]) tensor([[6]])
# Loss Agent0:0.00023962172285112678
# Loss Agent1:0.00023660166746192462
#
#  Iteration: 1366
# tensor([[8]]) tensor([[4]])
# Loss Agent0:0.00024356708036771247
# Loss Agent1:0.00026746495131929756
#
#  Iteration: 1367
# tensor([[7]]) tensor([[9]])
# Loss Agent0:0.0002840138088056318
# Loss Agent1:0.0003149793947039035
#
#  Iteration: 1368
# tensor([[7]]) tensor([[9]])
# Loss Agent0:0.0002886528292527338
# Loss Agent1:0.00028450854412382645
#
#  Iteration: 1369
# tensor([[8]]) tensor([[6]])
# Loss Agent0:0.0002806265365024052
# Loss Agent1:0.00022489222450852484
#
#  Iteration: 1370
# tensor([[8]]) tensor([[7]])
# Loss Agent0:0.00020285541569690224
# Loss Agent1:0.00020246787564253256
#
#  Iteration: 1371
# tensor([[9]]) tensor([[7]])
# Loss Agent0:0.00028670996733184273
# Loss Agent1:0.00020651107269154168
#
#  Iteration: 1372
# tensor([[9]]) tensor([[7]])
# Loss Agent0:0.00026737370005146396
# Loss Agent1:0.0003546577712891146
#
#  Iteration: 1373
# tensor([[9]]) tensor([[7]])
# Loss Agent0:0.0002563862731395173
# Loss Agent1:0.00025135350651933836
#
#  Iteration: 1374
# tensor([[9]]) tensor([[9]])
# Loss Agent0:0.0002907110787385418
# Loss Agent1:0.0002225278947269269
#
#  Iteration: 1375
# tensor([[9]]) tensor([[8]])
# Loss Agent0:0.00032511075635896557
# Loss Agent1:0.00024147585475232561
#
#  Iteration: 1376
# tensor([[6]]) tensor([[8]])
# Loss Agent0:0.0003266161999289195
# Loss Agent1:0.00025162382653013424
#
#  Iteration: 1377
# tensor([[9]]) tensor([[8]])
# Loss Agent0:0.0002852796913844045
# Loss Agent1:0.00020041471804061896
#
#  Iteration: 1378
# tensor([[9]]) tensor([[8]])
# Loss Agent0:0.00029946886516067097
# Loss Agent1:0.0003161580268580481
#
#  Iteration: 1379
# tensor([[2]]) tensor([[9]])
# Loss Agent0:0.0002614660992309588
# Loss Agent1:0.00023816994364947197
#
#  Iteration: 1380
# tensor([[8]]) tensor([[9]])
# Loss Agent0:0.0002631800466929427
# Loss Agent1:0.00019981667303753907
#
#  Iteration: 1381
# tensor([[8]]) tensor([[5]])
# Loss Agent0:0.0002722775410897208

# %% [markdown]
# ### Evaluate Network

# %%
policy_net1(state), policy_net2(state)
# Out:
# (tensor([0.0903, 0.0976], grad_fn=<AddBackward0>),
#  tensor([0.0897, 0.0977], grad_fn=<AddBackward0>))

# %%
target_net1(state), target_net2(state)
# Out:
# (tensor([0.0893, 0.0959], grad_fn=<AddBackward0>),
#  tensor([0.0891, 0.0934], grad_fn=<AddBackward0>))

# %% [markdown]
# ### Trace Path

# %%
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

plt.plot(moving_average(Qgrid[np.array(actions)][:,0],100), label = 'Avg q1', marker = 'o', c = 'b')
plt.plot(moving_average(Qgrid[np.array(actions)][:,1],100), label = 'Avg q2', marker = 'x', c = 'r')
plt.legend()
plt.title('Actions over Time')
plt.show()

# %%
plt.plot(moving_average(np.array(prices),100), label = 'Avg P', marker = 'o', c = 'b')
plt.plot(moving_average(np.array(quantities),100), label = 'Avg Q', marker = 'x', c = 'r')
plt.legend()
plt.title('Prices and Quantities over Time')
plt.show()
